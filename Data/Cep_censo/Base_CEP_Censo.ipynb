# %%
import pandas as pd

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cep_censo = pd.read_csv('/content/drive/MyDrive/Data Science/Puc Rio DS/02_Sprint Eng Dados/MVP_Data Engineering/Data/CEP-Censo/census_code_cep_coordinates.csv')

cep_censo
# Out:
#          POSTCODE        LON        LAT       CD_GEOCODI
# 0       00000-000 -46.663830 -22.257613  313490505000032
# 1       00000-001 -67.838738  -9.921660  120040105000325
# 2       00000-002 -67.880508  -9.882072  120040105000325
# 3       00000-003 -46.514443 -21.820570  315180005000240
# 4       00000-004 -67.893353  -9.882038  120040105000325
# ...           ...        ...        ...              ...
# 429989  99990-999 -48.562378 -25.574579  411820405000166
# 429990  99999-990 -48.563207 -25.567153  411820405000105
# 429991  99999-998 -41.092554 -20.853443  320120905000204
# 429992  99999-999 -43.998336 -22.912780  330260120000035
# 429993    Sem CEP -47.758636 -15.644745  530010805100314
#
# [429994 rows x 4 columns]

# %%
#Removendo o - das linhas de cep

cep_censo['POSTCODE'] = cep_censo['POSTCODE'].str.replace('-', '')

# %%
cep_censo['POSTCODE'] = pd.to_numeric(cep_censo['POSTCODE'], errors= 'coerce')

# %%
cep_censo
# Out:
#           POSTCODE        LON        LAT       CD_GEOCODI
# 0              0.0 -46.663830 -22.257613  313490505000032
# 1              1.0 -67.838738  -9.921660  120040105000325
# 2              2.0 -67.880508  -9.882072  120040105000325
# 3              3.0 -46.514443 -21.820570  315180005000240
# 4              4.0 -67.893353  -9.882038  120040105000325
# ...            ...        ...        ...              ...
# 429989  99990999.0 -48.562378 -25.574579  411820405000166
# 429990  99999990.0 -48.563207 -25.567153  411820405000105
# 429991  99999998.0 -41.092554 -20.853443  320120905000204
# 429992  99999999.0 -43.998336 -22.912780  330260120000035
# 429993         NaN -47.758636 -15.644745  530010805100314
#
# [429994 rows x 4 columns]

# %%
# Abrindo base ceps de cidade de SP

cep_sp = pd.read_csv('/content/drive/MyDrive/Data Science/Puc Rio DS/02_Sprint Eng Dados/MVP_Data Engineering/Data/cep_sp.csv')

cep_sp
# Out:
#            Cep                  Logradouro        Numero            Bairro  \
# 0      1001000                 Praça da Sé  - lado ímpar                Sé
# 1      1001001                 Praça da Sé    - lado par                Sé
# 2      1001010      Rua Filipe de Oliveira           NaN                Sé
# 3      1001900             Praça da Sé 108           NaN                Sé
# 4      1001901             Praça da Sé 371           NaN                Sé
# ...        ...                         ...           ...               ...
# 46390  5894420          Rua Serra do Pilar           NaN  Jardim Macedônia
# 46391  5894430       Rua Severiano Cardoso           NaN  Jardim Macedônia
# 46392  5894440  Rua Soriano de Albuquerque           NaN  Jardim Macedônia
# 46393  5894450    Rua Teixeira de Pascoais           NaN  Jardim Macedônia
# 46394  5894460              Rua Teo Cabral           NaN  Jardim Macedônia
#
#        Cod Cidade  Cod Estado
# 0            8966          26
# ...

# %%
# Abrindo base ceps de cidade de RJ

cep_rj = pd.read_csv('/content/drive/MyDrive/Data Science/Puc Rio DS/02_Sprint Eng Dados/MVP_Data Engineering/Data/cep_rj.csv')

cep_rj
# Out:
#             Cep                Logradouro      Numero     Bairro  Cod Cidade  \
# 0      20010000     Rua Primeiro de Março  Unnamed: 2     Centro        7764
# 1      20010010  Praça Quinze de Novembro         NaN     Centro        7764
# 2      20010020              Rua São José         NaN     Centro        7764
# 3      20010030           Travessa Tinoco         NaN     Centro        7764
# 4      20010040        Travessa Tocantins         NaN     Centro        7764
# ...         ...                       ...         ...        ...         ...
# 19879  23032640                 Rua Sussi         NaN  Guaratiba        7764
# 19880  23032660        Rua Trajano Galvão         NaN  Guaratiba        7764
# 19881  23032670            Rua Vasco Lima         NaN  Guaratiba        7764
# 19882  23032675            Travessa Delci         NaN  Guaratiba        7764
# 19883  23032680         Rua Vilhena Alves         NaN  Guaratiba        7764
#
#        Cod Estado
# 0              19
# ...

# %%
# concatenando ceps sp e rj

base_sp_rj = pd.concat([cep_sp, cep_rj])

# %%
base_sp_rj
# Out:
#             Cep              Logradouro        Numero     Bairro  Cod Cidade  \
# 0       1001000             Praça da Sé  - lado ímpar         Sé        8966
# 1       1001001             Praça da Sé    - lado par         Sé        8966
# 2       1001010  Rua Filipe de Oliveira           NaN         Sé        8966
# 3       1001900         Praça da Sé 108           NaN         Sé        8966
# 4       1001901         Praça da Sé 371           NaN         Sé        8966
# ...         ...                     ...           ...        ...         ...
# 19879  23032640               Rua Sussi           NaN  Guaratiba        7764
# 19880  23032660      Rua Trajano Galvão           NaN  Guaratiba        7764
# 19881  23032670          Rua Vasco Lima           NaN  Guaratiba        7764
# 19882  23032675          Travessa Delci           NaN  Guaratiba        7764
# 19883  23032680       Rua Vilhena Alves           NaN  Guaratiba        7764
#
#        Cod Estado
# 0              26
# ...

# %%
# separando apenas os ceps de sp e rio da base cep-censo

filtered_cep = pd.merge(cep_censo, base_sp_rj, left_on= 'POSTCODE', right_on= 'Cep', how= 'inner')

# %%
filtered_cep.drop(columns= ['POSTCODE', 'Numero'], inplace= True)

# %%
filtered_cep
# Out:
#              LON        LAT       CD_GEOCODI       Cep  \
# 0     -46.633693 -23.549325  355030878000005   1001000
# 1     -46.634252 -23.550460  355030878000005   1001001
# 2     -46.633682 -23.551317  355030878000004   1001010
# 3     -46.634751 -23.548560  355030878000006   1002000
# 4     -46.635394 -23.548349  355030878000005   1002001
# ...          ...        ...              ...       ...
# 43407 -43.638861 -22.975777  330455705310162  23032630
# 43408 -43.638952 -22.971355  330455705310162  23032640
# 43409 -43.647551 -22.973394  330455705310011  23032660
# 43410 -43.653872 -22.975990  330455705310214  23032670
# 43411 -43.646246 -22.976294  330455705310119  23032680
#
#                    Logradouro     Bairro  Cod Cidade  Cod Estado
# 0                 Praça da Sé         Sé        8966          26
# 1                 Praça da Sé         Sé        8966          26
# 2      Rua Filipe de Oliveira         Sé        8966          26
# ...

# %%
# Specify the path where you want to save the CSV file
csv_file_path = '/content/drive/My Drive/cep_censo_filtrado.csv'

# Save the DataFrame to CSV
filtered_cep.to_csv(csv_file_path, index=False)

# %%
import pandas as pd

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cep_censo = pd.read_csv('/content/drive/MyDrive/Data Science/Puc Rio DS/02_Sprint Eng Dados/MVP_Data Engineering/Data/CEP-Censo/census_code_cep_coordinates.csv')

cep_censo
# Out:
#          POSTCODE        LON        LAT       CD_GEOCODI
# 0       00000-000 -46.663830 -22.257613  313490505000032
# 1       00000-001 -67.838738  -9.921660  120040105000325
# 2       00000-002 -67.880508  -9.882072  120040105000325
# 3       00000-003 -46.514443 -21.820570  315180005000240
# 4       00000-004 -67.893353  -9.882038  120040105000325
# ...           ...        ...        ...              ...
# 429989  99990-999 -48.562378 -25.574579  411820405000166
# 429990  99999-990 -48.563207 -25.567153  411820405000105
# 429991  99999-998 -41.092554 -20.853443  320120905000204
# 429992  99999-999 -43.998336 -22.912780  330260120000035
# 429993    Sem CEP -47.758636 -15.644745  530010805100314
#
# [429994 rows x 4 columns]

# %%
cities.columns
# Out:
# Index(['1', 'Abacate da Pedreira (Macapá)', '4'], dtype='object')

# %%
cities[cities['Abacate da Pedreira (Macapá)']  == 'São Paulo']
# Out:
#          1 Abacate da Pedreira (Macapá)   4
# 8948  8966                    São Paulo  26

# %%
sp1 = pd.read_csv('/content/drive/MyDrive/Data Science/Puc Rio DS/02_Sprint Eng Dados/MVP_Data Engineering/Data/Cep/sp.cepaberto_parte_1.csv')

sp1
# Out:
#        01001000             Praça da Sé - lado ímpar               Sé  8966  \
# 0       1001001             Praça da Sé   - lado par               Sé  8966
# 1       1001010  Rua Filipe de Oliveira          NaN               Sé  8966
# 2       1001900         Praça da Sé 108          NaN               Sé  8966
# 3       1001901         Praça da Sé 371          NaN               Sé  8966
# 4       1001902         Praça da Sé 385          NaN               Sé  8966
# ...         ...                     ...          ...              ...   ...
# 60164   6783055          Alameda da Paz          NaN  Jardim Saporito  9503
# 60165   6783060        Rua Campos Sales          NaN  Jardim Saporito  9503
# 60166   6783070            Rua Getulina          NaN    Jardim Record  9503
# 60167   6783080     Rua Sadayoshi Satto          NaN    Jardim Record  9503
# 60168   6783090   Rua Giuseppina Comino          NaN    Jardim Record  9503
#
#        26
# 0      26
# 1      26
# 2      26
# ...

# %%
cep_sp = sp1[sp1["8966"] == 8966]
cep_sp
# Out:
#        01001000                 Praça da Sé - lado ímpar                Sé  \
# 0       1001001                 Praça da Sé   - lado par                Sé
# 1       1001010      Rua Filipe de Oliveira          NaN                Sé
# 2       1001900             Praça da Sé 108          NaN                Sé
# 3       1001901             Praça da Sé 371          NaN                Sé
# 4       1001902             Praça da Sé 385          NaN                Sé
# ...         ...                         ...          ...               ...
# 46389   5894420          Rua Serra do Pilar          NaN  Jardim Macedônia
# 46390   5894430       Rua Severiano Cardoso          NaN  Jardim Macedônia
# 46391   5894440  Rua Soriano de Albuquerque          NaN  Jardim Macedônia
# 46392   5894450    Rua Teixeira de Pascoais          NaN  Jardim Macedônia
# 46393   5894460              Rua Teo Cabral          NaN  Jardim Macedônia
#
#        8966  26
# 0      8966  26
# 1      8966  26
# ...

# %%
# Specify the path where you want to save the CSV file
csv_file_path = '/content/drive/My Drive/cep_sp.csv'

# Save the DataFrame to CSV
cep_sp.to_csv(csv_file_path, index=False)

# %%
cities[cities['Abacate da Pedreira (Macapá)']  == 'Rio de Janeiro']
# Out:
#          1 Abacate da Pedreira (Macapá)   4
# 7749  7764               Rio de Janeiro  19

# %%
rj1 = pd.read_csv('/content/drive/MyDrive/Data Science/Puc Rio DS/02_Sprint Eng Dados/MVP_Data Engineering/Data/Cep/rj.cepaberto_parte_1.csv')

rj1
# Out:
#        20010000         Rua Primeiro de Março Unnamed: 2     Centro  7764  19
# 0      20010010      Praça Quinze de Novembro        NaN     Centro  7764  19
# 1      20010020                  Rua São José        NaN     Centro  7764  19
# 2      20010030               Travessa Tinoco        NaN     Centro  7764  19
# 3      20010040            Travessa Tocantins        NaN     Centro  7764  19
# 4      20010050  Travessa Trajano de Carvalho        NaN     Centro  7764  19
# ...         ...                           ...        ...        ...   ...  ..
# 19878  23032640                     Rua Sussi        NaN  Guaratiba  7764  19
# 19879  23032660            Rua Trajano Galvão        NaN  Guaratiba  7764  19
# 19880  23032670                Rua Vasco Lima        NaN  Guaratiba  7764  19
# 19881  23032675                Travessa Delci        NaN  Guaratiba  7764  19
# 19882  23032680             Rua Vilhena Alves        NaN  Guaratiba  7764  19
#
# [19883 rows x 6 columns]

# %%
cep_rj = rj1[rj1["7764"] == 7764]
cep_rj
# Out:
#        20010000         Rua Primeiro de Março Unnamed: 2     Centro  7764  19
# 0      20010010      Praça Quinze de Novembro        NaN     Centro  7764  19
# 1      20010020                  Rua São José        NaN     Centro  7764  19
# 2      20010030               Travessa Tinoco        NaN     Centro  7764  19
# 3      20010040            Travessa Tocantins        NaN     Centro  7764  19
# 4      20010050  Travessa Trajano de Carvalho        NaN     Centro  7764  19
# ...         ...                           ...        ...        ...   ...  ..
# 19878  23032640                     Rua Sussi        NaN  Guaratiba  7764  19
# 19879  23032660            Rua Trajano Galvão        NaN  Guaratiba  7764  19
# 19880  23032670                Rua Vasco Lima        NaN  Guaratiba  7764  19
# 19881  23032675                Travessa Delci        NaN  Guaratiba  7764  19
# 19882  23032680             Rua Vilhena Alves        NaN  Guaratiba  7764  19
#
# [19883 rows x 6 columns]

# %%
# Specify the path where you want to save the CSV file
csv_file_path = '/content/drive/My Drive/cep_rj.csv'

# Save the DataFrame to CSV
cep_rj.to_csv(csv_file_path, index=False)

# %%
cep_sp = pd.read_csv('/content/drive/MyDrive/Data Science/Puc Rio DS/02_Sprint Eng Dados/MVP_Data Engineering/Data/cep_sp.csv')

cep_sp
# Out:
#        01001000                 Praça da Sé - lado ímpar                Sé  \
# 0       1001001                 Praça da Sé   - lado par                Sé
# 1       1001010      Rua Filipe de Oliveira          NaN                Sé
# 2       1001900             Praça da Sé 108          NaN                Sé
# 3       1001901             Praça da Sé 371          NaN                Sé
# 4       1001902             Praça da Sé 385          NaN                Sé
# ...         ...                         ...          ...               ...
# 46389   5894420          Rua Serra do Pilar          NaN  Jardim Macedônia
# 46390   5894430       Rua Severiano Cardoso          NaN  Jardim Macedônia
# 46391   5894440  Rua Soriano de Albuquerque          NaN  Jardim Macedônia
# 46392   5894450    Rua Teixeira de Pascoais          NaN  Jardim Macedônia
# 46393   5894460              Rua Teo Cabral          NaN  Jardim Macedônia
#
#        8966  26
# 0      8966  26
# 1      8966  26
# ...

# %%
cep_sp.columns
# Out:
# Index(['01001000', 'Praça da Sé', '- lado ímpar', 'Sé', '8966', '26'], dtype='object')

# %%
cep_sp.loc[-1] = ['01001000', 'Praça da Sé', '- lado ímpar', 'Sé', '8966', '26']
cep_sp.index = cep_sp.index + 1
cep_sp = cep_sp.sort_index()

# %%
cep_sp.reset_index()
# Out:
#        index  01001000                 Praça da Sé  - lado ímpar  \
# 0          0  01001000                 Praça da Sé  - lado ímpar
# 1          1   1001001                 Praça da Sé    - lado par
# 2          2   1001010      Rua Filipe de Oliveira           NaN
# 3          3   1001900             Praça da Sé 108           NaN
# 4          4   1001901             Praça da Sé 371           NaN
# ...      ...       ...                         ...           ...
# 46390  46390   5894420          Rua Serra do Pilar           NaN
# 46391  46391   5894430       Rua Severiano Cardoso           NaN
# 46392  46392   5894440  Rua Soriano de Albuquerque           NaN
# 46393  46393   5894450    Rua Teixeira de Pascoais           NaN
# 46394  46394   5894460              Rua Teo Cabral           NaN
#
#                      Sé  8966  26
# 0                    Sé  8966  26
# 1                    Sé  8966  26
# 2                    Sé  8966  26
# 3                    Sé  8966  26
# ...

# %%
cep_sp.columns = ['Cep', 'Logradouro', 'Numero', 'Bairro', 'Cod Cidade', 'Cod Estado']

# %%
cep_sp.columns
# Out:
# Index(['Cep', 'Logradouro', 'Numero', 'Bairro', 'Cod Cidade', 'Cod Estado'], dtype='object')

# %%
cep_sp
# Out:
#             Cep                  Logradouro        Numero            Bairro  \
# 0      01001000                 Praça da Sé  - lado ímpar                Sé
# 1       1001001                 Praça da Sé    - lado par                Sé
# 2       1001010      Rua Filipe de Oliveira           NaN                Sé
# 3       1001900             Praça da Sé 108           NaN                Sé
# 4       1001901             Praça da Sé 371           NaN                Sé
# ...         ...                         ...           ...               ...
# 46390   5894420          Rua Serra do Pilar           NaN  Jardim Macedônia
# 46391   5894430       Rua Severiano Cardoso           NaN  Jardim Macedônia
# 46392   5894440  Rua Soriano de Albuquerque           NaN  Jardim Macedônia
# 46393   5894450    Rua Teixeira de Pascoais           NaN  Jardim Macedônia
# 46394   5894460              Rua Teo Cabral           NaN  Jardim Macedônia
#
#       Cod Cidade Cod Estado
# ...

# %%
# Specify the path where you want to save the CSV file
csv_file_path = '/content/drive/My Drive/cep_sp.csv'

# Save the DataFrame to CSV
cep_sp.to_csv(csv_file_path, index=False)

# %%
cep_rj = pd.read_csv('/content/drive/MyDrive/Data Science/Puc Rio DS/02_Sprint Eng Dados/MVP_Data Engineering/Data/cep_rj.csv')

cep_rj
# Out:
#        20010000         Rua Primeiro de Março Unnamed: 2     Centro  7764  19
# 0      20010010      Praça Quinze de Novembro        NaN     Centro  7764  19
# 1      20010020                  Rua São José        NaN     Centro  7764  19
# 2      20010030               Travessa Tinoco        NaN     Centro  7764  19
# 3      20010040            Travessa Tocantins        NaN     Centro  7764  19
# 4      20010050  Travessa Trajano de Carvalho        NaN     Centro  7764  19
# ...         ...                           ...        ...        ...   ...  ..
# 19878  23032640                     Rua Sussi        NaN  Guaratiba  7764  19
# 19879  23032660            Rua Trajano Galvão        NaN  Guaratiba  7764  19
# 19880  23032670                Rua Vasco Lima        NaN  Guaratiba  7764  19
# 19881  23032675                Travessa Delci        NaN  Guaratiba  7764  19
# 19882  23032680             Rua Vilhena Alves        NaN  Guaratiba  7764  19
#
# [19883 rows x 6 columns]

# %%
cep_rj.columns
# Out:
# Index(['20010000', 'Rua Primeiro de Março', 'Unnamed: 2', 'Centro', '7764',
#        '19'],
#       dtype='object')

# %%
cep_rj.loc[-1] = ['20010000', 'Rua Primeiro de Março', 'Unnamed: 2', 'Centro', '7764', '19']
cep_rj.index = cep_rj.index + 1
cep_rj = cep_rj.sort_index()

# %%
cep_rj.columns = ['Cep', 'Logradouro', 'Numero', 'Bairro', 'Cod Cidade', 'Cod Estado']

# %%
cep_rj
# Out:
#             Cep                Logradouro      Numero     Bairro Cod Cidade  \
# 0      20010000     Rua Primeiro de Março  Unnamed: 2     Centro       7764
# 1      20010010  Praça Quinze de Novembro         NaN     Centro       7764
# 2      20010020              Rua São José         NaN     Centro       7764
# 3      20010030           Travessa Tinoco         NaN     Centro       7764
# 4      20010040        Travessa Tocantins         NaN     Centro       7764
# ...         ...                       ...         ...        ...        ...
# 19879  23032640                 Rua Sussi         NaN  Guaratiba       7764
# 19880  23032660        Rua Trajano Galvão         NaN  Guaratiba       7764
# 19881  23032670            Rua Vasco Lima         NaN  Guaratiba       7764
# 19882  23032675            Travessa Delci         NaN  Guaratiba       7764
# 19883  23032680         Rua Vilhena Alves         NaN  Guaratiba       7764
#
#       Cod Estado
# 0             19
# 1             19
# ...

# %%
# Specify the path where you want to save the CSV file
csv_file_path = '/content/drive/My Drive/cep_rj.csv'

# Save the DataFrame to CSV
cep_rj.to_csv(csv_file_path, index=False)

# %% [markdown]
# ## cep
